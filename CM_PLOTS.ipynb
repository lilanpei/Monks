# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import  pylab

# %% [markdown]
# ### Point mainDir to the directory where the reported experiments live

# %%
mainDir='d:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\sgdnonnestrovfinal'

# %%
#here, point to the folder that should contain the output plots
plotsDir='D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\sgdnonnestrovfinalPLOTs'

# %%
top20PLotsDir = 'D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\sgdnonnestrovfinalPLOTsTop20'

# %%
p = pd.read_csv(mainDir+'\\avgMSEs',delimiter=',',header=None)

# %%
p.columns=['name','avgMSE']

# %%
p
# Out:
#                                 name     avgMSE
# 0         hdn100_k5_lr0.005_reg0_mo0   8.016682
# 1     hdn100_k5_lr0.005_reg0.001_mo0   3.049197
# 2          hdn100_k5_lr0.01_reg0_mo0  10.730731
# 3      hdn100_k5_lr0.01_reg0.001_mo0   3.292397
# 4       hdn100_k5_lr0.005_reg0_mo0.5  14.727322
# 5   hdn100_k5_lr0.005_reg0.001_mo0.5   3.006829
# 6        hdn100_k5_lr0.01_reg0_mo0.5  12.050793
# 7    hdn100_k5_lr0.01_reg0.001_mo0.5   3.039885
# 8          hdn80_k5_lr0.005_reg0_mo0   8.045195
# 9      hdn80_k5_lr0.005_reg0.001_mo0   3.155544
# 10          hdn80_k5_lr0.01_reg0_mo0   9.094387
# 11      hdn80_k5_lr0.01_reg0.001_mo0   3.040099
# 12       hdn80_k5_lr0.005_reg0_mo0.5   9.527674
# 13   hdn80_k5_lr0.005_reg0.001_mo0.5   3.040472
# 14        hdn80_k5_lr0.01_reg0_mo0.5  10.507708
# 15    hdn80_k5_lr0.01_reg0.001_mo0.5   2.969773
# 16         hdn60_k5_lr0.005_reg0_mo0   9.445451
# 17     hdn60_k5_lr0.005_reg0.001_mo0   3.088708
# 18          hdn60_k5_lr0.01_reg0_mo0   9.700246
# ...

# %% [markdown]
# Reporting the results sorted by their average MSE

# %%
result = p.sort_values(by=['avgMSE'])

# %%
result.to_csv(plotsDir+'\\AverageMSEsSortedAscending.csv')

# %%
result
# Out:
#                                 name     avgMSE
# 33     hdn20_k5_lr0.005_reg0.001_mo0   2.928588
# 15    hdn80_k5_lr0.01_reg0.001_mo0.5   2.969773
# 27      hdn40_k5_lr0.01_reg0.001_mo0   2.976110
# 39    hdn20_k5_lr0.01_reg0.001_mo0.5   2.982251
# 5   hdn100_k5_lr0.005_reg0.001_mo0.5   3.006829
# 23    hdn60_k5_lr0.01_reg0.001_mo0.5   3.007029
# 29   hdn40_k5_lr0.005_reg0.001_mo0.5   3.011795
# 25     hdn40_k5_lr0.005_reg0.001_mo0   3.011973
# 35      hdn20_k5_lr0.01_reg0.001_mo0   3.017527
# 21   hdn60_k5_lr0.005_reg0.001_mo0.5   3.032281
# 37   hdn20_k5_lr0.005_reg0.001_mo0.5   3.033151
# 7    hdn100_k5_lr0.01_reg0.001_mo0.5   3.039885
# 11      hdn80_k5_lr0.01_reg0.001_mo0   3.040099
# 13   hdn80_k5_lr0.005_reg0.001_mo0.5   3.040472
# 1     hdn100_k5_lr0.005_reg0.001_mo0   3.049197
# 19      hdn60_k5_lr0.01_reg0.001_mo0   3.069511
# 17     hdn60_k5_lr0.005_reg0.001_mo0   3.088708
# 9      hdn80_k5_lr0.005_reg0.001_mo0   3.155544
# 31    hdn40_k5_lr0.01_reg0.001_mo0.5   3.280586
# ...

# %% [markdown]
# ### We see that the following are the top 20 settings

# %%
top20=p.sort_values(by=['avgMSE']).head(20)

# %%
top20
# Out:
#                                 name    avgMSE
# 33     hdn20_k5_lr0.005_reg0.001_mo0  2.928588
# 15    hdn80_k5_lr0.01_reg0.001_mo0.5  2.969773
# 27      hdn40_k5_lr0.01_reg0.001_mo0  2.976110
# 39    hdn20_k5_lr0.01_reg0.001_mo0.5  2.982251
# 5   hdn100_k5_lr0.005_reg0.001_mo0.5  3.006829
# 23    hdn60_k5_lr0.01_reg0.001_mo0.5  3.007029
# 29   hdn40_k5_lr0.005_reg0.001_mo0.5  3.011795
# 25     hdn40_k5_lr0.005_reg0.001_mo0  3.011973
# 35      hdn20_k5_lr0.01_reg0.001_mo0  3.017527
# 21   hdn60_k5_lr0.005_reg0.001_mo0.5  3.032281
# 37   hdn20_k5_lr0.005_reg0.001_mo0.5  3.033151
# 7    hdn100_k5_lr0.01_reg0.001_mo0.5  3.039885
# 11      hdn80_k5_lr0.01_reg0.001_mo0  3.040099
# 13   hdn80_k5_lr0.005_reg0.001_mo0.5  3.040472
# 1     hdn100_k5_lr0.005_reg0.001_mo0  3.049197
# 19      hdn60_k5_lr0.01_reg0.001_mo0  3.069511
# 17     hdn60_k5_lr0.005_reg0.001_mo0  3.088708
# 9      hdn80_k5_lr0.005_reg0.001_mo0  3.155544
# 31    hdn40_k5_lr0.01_reg0.001_mo0.5  3.280586
# ...

# %%
top20.to_csv(top20PLotsDir+'\\AverageMSEsSortedAscending.csv')

# %%
for index, row  in result.iterrows():
    #crv = pd.read_csv('D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv = pd.read_csv(mainDir+'\\'+row[0]+'\\0_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv.columns=['fold0_train','fold0_val']
    ax=crv.plot(figsize=(6,4))

    for i in range(1,5):
        crv = pd.read_csv(mainDir+'\\'+row[0]+'\\'+str(i)+'_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
        crv.columns=['fold'+str(i)+'_train','fold'+str(i)+'_val']
        crv.plot(ax=ax)
    #plt.ylim([1, 10])
    pylab.xlabel('epochs')
    pylab.ylabel('MSE')
    plt.title(row[0]+' avgValidationMSE:'+str(row[1]))
    plt.ylim([0,10])
    #plt.show()
    plt.savefig(plotsDir+'\\'+row[0]+' avgValidationMSE_'+str(row[1])+'.png')
# Out:
# c:\users\ahmad\appdata\local\programs\python\python35\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#plot top 20
for index, row  in top20.iterrows():
    #crv = pd.read_csv('D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv = pd.read_csv(mainDir+'\\'+row[0]+'\\0_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv.columns=['fold0_train','fold0_val']
    ax=crv.plot(figsize=(6,4))

    for i in range(1,5):
        crv = pd.read_csv(mainDir+'\\'+row[0]+'\\'+str(i)+'_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
        crv.columns=['fold'+str(i)+'_train','fold'+str(i)+'_val']
        crv.plot(ax=ax)
    #plt.ylim([1, 10])
    pylab.xlabel('epochs')
    pylab.ylabel('MSE')
    plt.title(row[0]+' avgValidationMSE:'+str(row[1]))
    plt.ylim([0,10])
    #plt.show()
    plt.savefig(top20PLotsDir+'\\'+row[0]+' avgValidationMSE_'+str(row[1])+'.png')
# Out:
# c:\users\ahmad\appdata\local\programs\python\python35\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
for index, row  in result.iterrows():
    #crv = pd.read_csv('D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\scatters\\'+row[0]+'scatter.txt',header=None)
    crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\scatters\\'+row[0]+'scatter.txt',header=None)
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_4\\scatters\\'+row[0]+'scatter.txt',header=None)
    crv.columns=['a','b','c','d']
    crv.columns=['a','b','c','d']
    ax = crv.plot( figsize=(8,5),  kind='scatter', x='a', y='b',color='DarkBlue', label='Output',marker='x');   
    crv.plot(kind='scatter', x='c', y='d',color='Red', label='Target', ax=ax,marker='<');
    plt.title(row[0]+' MEE:'+str(row[1]))

# %%
plt.show()
