# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import  pylab

# %% [markdown]
# ### Point mainDir to the directory where the reported experiments live

# %%
mainDir='D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\adamexperimentsfinal'

# %%
#here, point to the folder that should contain the output plots
plotsDir='D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\adamexperimentsfinalPLOTS'

# %%
p = pd.read_csv(mainDir+'\\avgMSEs',delimiter=',',header=None)

# %%
p.columns=['name','avgMSE']

# %%
p
# Out:
#                           name     avgMSE
# 0       hdn100_k5_lr0.001_reg0  16.518333
# 1   hdn100_k5_lr0.001_reg0.001   3.045349
# 2    hdn100_k5_lr0.001_reg0.01   3.209265
# 3       hdn100_k5_lr0.005_reg0   8.023759
# 4   hdn100_k5_lr0.005_reg0.001   3.269013
# 5    hdn100_k5_lr0.005_reg0.01   3.285520
# 6        hdn100_k5_lr0.01_reg0   6.595081
# 7    hdn100_k5_lr0.01_reg0.001   3.572211
# 8     hdn100_k5_lr0.01_reg0.01   3.503596
# 9        hdn90_k5_lr0.001_reg0  13.080838
# 10   hdn90_k5_lr0.001_reg0.001   3.041776
# 11    hdn90_k5_lr0.001_reg0.01   3.190487
# 12       hdn90_k5_lr0.005_reg0   8.781672
# 13   hdn90_k5_lr0.005_reg0.001   3.119385
# 14    hdn90_k5_lr0.005_reg0.01   3.223634
# 15        hdn90_k5_lr0.01_reg0   7.027928
# 16    hdn90_k5_lr0.01_reg0.001   3.587555
# 17     hdn90_k5_lr0.01_reg0.01   3.412565
# 18       hdn80_k5_lr0.001_reg0  12.155848
# 19   hdn80_k5_lr0.001_reg0.001   3.024321
# 20    hdn80_k5_lr0.001_reg0.01   3.193583
# 21       hdn80_k5_lr0.005_reg0   8.696365
# 22   hdn80_k5_lr0.005_reg0.001   2.974550
# 23    hdn80_k5_lr0.005_reg0.01   3.230368
# 24        hdn80_k5_lr0.01_reg0   6.810848
# 25    hdn80_k5_lr0.01_reg0.001   3.542237
# 26     hdn80_k5_lr0.01_reg0.01   3.542149
# 27       hdn70_k5_lr0.001_reg0   9.530662
# 28   hdn70_k5_lr0.001_reg0.001   3.259838
# 29    hdn70_k5_lr0.001_reg0.01   3.189581
# ..                         ...        ...
# 60        hdn40_k5_lr0.01_reg0   5.555783
# 61    hdn40_k5_lr0.01_reg0.001   3.478553
# 62     hdn40_k5_lr0.01_reg0.01   3.689504
# 63       hdn30_k5_lr0.001_reg0   5.091462
# 64   hdn30_k5_lr0.001_reg0.001   2.941200
# 65    hdn30_k5_lr0.001_reg0.01   3.219830
# 66       hdn30_k5_lr0.005_reg0   5.403189
# 67   hdn30_k5_lr0.005_reg0.001   3.103125
# 68    hdn30_k5_lr0.005_reg0.01   3.050320
# 69        hdn30_k5_lr0.01_reg0   6.159610
# 70    hdn30_k5_lr0.01_reg0.001   3.255521
# 71     hdn30_k5_lr0.01_reg0.01   3.473298
# 72       hdn20_k5_lr0.001_reg0   4.100140
# 73   hdn20_k5_lr0.001_reg0.001   2.869099
# 74    hdn20_k5_lr0.001_reg0.01   3.205499
# 75       hdn20_k5_lr0.005_reg0   4.419040
# 76   hdn20_k5_lr0.005_reg0.001   3.068522
# 77    hdn20_k5_lr0.005_reg0.01   3.146856
# 78        hdn20_k5_lr0.01_reg0   5.073017
# 79    hdn20_k5_lr0.01_reg0.001   3.277222
# 80     hdn20_k5_lr0.01_reg0.01   3.367468
# 81       hdn10_k5_lr0.001_reg0   3.463317
# 82   hdn10_k5_lr0.001_reg0.001   3.156930
# 83    hdn10_k5_lr0.001_reg0.01   3.230486
# 84       hdn10_k5_lr0.005_reg0   4.491925
# 85   hdn10_k5_lr0.005_reg0.001   3.512420
# 86    hdn10_k5_lr0.005_reg0.01   3.398408
# 87        hdn10_k5_lr0.01_reg0   4.986573
# 88    hdn10_k5_lr0.01_reg0.001   3.449804
# 89     hdn10_k5_lr0.01_reg0.01   3.468600
#
# [90 rows x 2 columns]

# %% [markdown]
# Reporting the results sorted by their average MSE

# %%
result = p.sort_values(by=['avgMSE'])

# %%
result.to_csv(plotsDir+'\\AverageMSEsSortedAscending.csv')

# %% [markdown]
# ### We see that the following are the top 10 settings

# %%
top20=p.sort_values(by=['avgMSE']).head(20)

# %%
top20
# Out:
#                           name    avgMSE
# 73   hdn20_k5_lr0.001_reg0.001  2.869099
# 64   hdn30_k5_lr0.001_reg0.001  2.941200
# 37   hdn60_k5_lr0.001_reg0.001  2.945531
# 22   hdn80_k5_lr0.005_reg0.001  2.974550
# 55   hdn40_k5_lr0.001_reg0.001  2.980975
# 46   hdn50_k5_lr0.001_reg0.001  2.991854
# 19   hdn80_k5_lr0.001_reg0.001  3.024321
# 10   hdn90_k5_lr0.001_reg0.001  3.041776
# 1   hdn100_k5_lr0.001_reg0.001  3.045349
# 68    hdn30_k5_lr0.005_reg0.01  3.050320
# 31   hdn70_k5_lr0.005_reg0.001  3.064476
# 76   hdn20_k5_lr0.005_reg0.001  3.068522
# 67   hdn30_k5_lr0.005_reg0.001  3.103125
# 59    hdn40_k5_lr0.005_reg0.01  3.106687
# 13   hdn90_k5_lr0.005_reg0.001  3.119385
# 58   hdn40_k5_lr0.005_reg0.001  3.139477
# 50    hdn50_k5_lr0.005_reg0.01  3.139826
# 77    hdn20_k5_lr0.005_reg0.01  3.146856
# 82   hdn10_k5_lr0.001_reg0.001  3.156930
# 40   hdn60_k5_lr0.005_reg0.001  3.164501

# %%
top20.to_csv(plotsDir+'top20'+'\\AverageMSEsSortedAscending.csv')

# %%
for index, row  in top20.iterrows():
    #crv = pd.read_csv('D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv = pd.read_csv(mainDir+'\\'+row[0]+'\\0_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv.columns=['fold0_train','fold0_val']
    ax=crv.plot(figsize=(6,4))

    for i in range(1,5):
        crv = pd.read_csv(mainDir+'\\'+row[0]+'\\'+str(i)+'_learningCurve.txt',header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
        crv.columns=['fold'+str(i)+'_train','fold'+str(i)+'_val']
        crv.plot(ax=ax)
    #plt.ylim([1, 10])
    pylab.xlabel('epochs')
    pylab.ylabel('MSE')
    plt.title(row[0]+' avgValidationMSE:'+str(row[1]))
    plt.ylim([0,10])
    #plt.show()
    plt.savefig(plotsDir+'top20'+'\\'+row[0]+' avgValidationMSE_'+str(row[1])+'.png')
# Out:
# c:\users\ahmad\appdata\local\programs\python\python35\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
for index, row  in result.iterrows():
    #crv = pd.read_csv('D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\scatters\\'+row[0]+'scatter.txt',header=None)
    crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\ML\\Monk\\AA1_Monks\\AA1_CUP\\bin\\Debug\\scatters\\'+row[0]+'scatter.txt',header=None)
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_4\\scatters\\'+row[0]+'scatter.txt',header=None)
    crv.columns=['a','b','c','d']
    crv.columns=['a','b','c','d']
    ax = crv.plot( figsize=(8,5),  kind='scatter', x='a', y='b',color='DarkBlue', label='Output',marker='x');   
    crv.plot(kind='scatter', x='c', y='d',color='Red', label='Target', ax=ax,marker='<');
    plt.title(row[0]+' MEE:'+str(row[1]))

# %%
plt.show()
