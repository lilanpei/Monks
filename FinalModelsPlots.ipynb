# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
mainDir='C:\\Users\\ahmad\\Documents\\monks\\Monks\\AA1_Monks\\AA1_CUP\\bin\\Release\\'

# %%
def plotACurve(filename):
    crv = pd.read_csv(mainDir+filename,header=None,usecols=[0,1])
    #crv = pd.read_csv('E:\\Dropbox\\Master Course\\SEM-3\\ML\Monk\\trainingLogs\\lanpei\\Passed_tries_5\\learningCurves\\'+row[0]+'learningCurve.txt',header=None,usecols=[0,1])
    crv.columns=['train','validation']
    crv.plot(figsize=(8,6))
    #plt.ylim([1, 10])
    plt.title(filename.replace('.txt',''))
    plt.ylim([0,10])
    plt.xlabel('epochs')
    plt.ylabel('MSE')
    plt.show()

# %%
fileNames=['standardized_adam_hdn100_lr0.001_reg0.001.txt','standardized_adam_hdn80_lr0.001_reg0.001.txt','standardized_sgdnestrov_hdn100_lr0.005_reg0.001.txt']

# %%
for f in fileNames:
    plotACurve(f)
