# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
# %matplotlib inline

# %%
location2DatasetTrain = 'D:\\dropbox\\Dropbox\\Master Course\\SEM-3\\ML\\CM_CUP_Datasets\\train'

# %% [markdown]
# ## Loading the trainingset of CUP
# #### the version we used is trimmed, removing the information banner before the data

# %%
df = pd.read_csv(location2DatasetTrain,delimiter=',',header=None, usecols =list(range(1,13)))

# %% [markdown]
# ### a summary statistics about the data

# %%
df.describe()
# Out:
#                 1            2            3            4            5   \
# count  1016.000000  1016.000000  1016.000000  1016.000000  1016.000000
# mean      0.022578     0.012822     0.014936    -0.005945    -0.006026
# std       0.980158     0.983463     0.994274     1.011651     0.990182
# min      -2.689221    -1.657394    -1.799302    -1.869477    -1.581593
# 25%      -0.580706    -0.925518    -0.966430    -0.985472    -0.984400
# 50%      -0.122333     0.115999     0.104406     0.214248     0.090547
# 75%       0.611064     0.932322     0.892661     0.845680     0.866898
# max       2.352881     1.833093     1.948624     1.919115     1.762688
#
#                 6            7            8            9            10  \
# count  1016.000000  1016.000000  1016.000000  1016.000000  1016.000000
# mean      0.017489    -0.004397     0.022725    -0.010100     0.000230
# std       0.988752     1.001909     1.006664     1.002184     0.997642
# ...

# %%
df.dtypes
# Out:
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11    float64
# 12    float64
# dtype: object

# %% [markdown]
# ### plotting the correlation between the different data to have an idea about the problem and the best suitable model to solve it

# %%
pd.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EE1C4F28>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5D5EC18>]], dtype=object)

# %% [markdown]
# ### From the previous plot, it is very clear that the realtion between the inputs and the outputs are mostly non linear,
# ### A Linear model trying to solve the problem will be in a complete disadvantage
